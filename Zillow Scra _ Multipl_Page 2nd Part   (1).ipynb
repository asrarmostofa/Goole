# %%
import os
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time
import sys
import numpy as np
import pandas as pd
import regex as re
import requests
import lxml
from lxml.html.soupparser import fromstring
#import prettify
import numbers
#import htmltext
import html_text

# %%
#set some display settings for notebooks
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)
pd.set_option('display.max_colwidth', None)

# %%
#pip install html-text

# %%
req_headers = {
    'authority': 'www.zillow.com',
    'accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'accept-language': 'en-US,en;q=0.9,bn;q=0.8',
    'cache-control': 'max-age=0',
    # Requests sorts cookies= alphabetically
    # 'cookie': f"_ga=GA1.2.977865423.1653826084; zjs_user_id=null; zg_anonymous_id=%22f3b4235f-a466-4fcf-8993-15ed2e7c4057%22; _pxvid=fbeeb505-df47-11ec-9527-536e776b4c51; _gcl_au=1.1.645400461.1653826085; __pdst=6def93f0ef434f37a1638ee29fb9f6a5; _fbp=fb.1.1653826085977.510291915; _cs_c=0; _pin_unauth=dWlkPU5HRTNPV1E1Tm1ZdE16RXhNUzAwWWpZM0xUaGlPVFl0TldReVpXUm1PREZpTUdFeg; zjs_anonymous_id=%22b9f8f8ec-4194-471f-bb5a-62fbda6f60d7%22; __gads=ID=e3e98628d28e8902:T=1653826115:S=ALNI_Mb2pXs7qDV2UQeLK5w9hJhKrr1eUg; optimizelyEndUserId=oeu1653826288550r0.7453811349308455; zguid=24|%24b9f8f8ec-4194-471f-bb5a-62fbda6f60d7; g_state={\"i_p\":1657430200746,\"i_l\":4}; _hp2_id.1215457233=%7B%22userId%22%3A%223701647631060968%22%2C%22pageviewId%22%3A%224400298535943158%22%2C%22sessionId%22%3A%225844116094505631%22%2C%22identity%22%3Anull%2C%22trackerVersion%22%3A%224.0%22%7D; _cs_id=62ee3a3b-b8fc-a013-e16e-6fb174b77c6b.1653826087.4.1655641704.1655641704.1.1687990087103; JSESSIONID=34729133B33247E315D92DBCC162BC4B; zgsession=1|97f36cc1-b172-4b7e-b07e-078e32147c7d; _gid=GA1.2.1301542775.1657184680; pxcts=c6efb8b3-fdd3-11ec-b54c-526f774d4748; _px3=279ec08a9d845fff9cc9e2eee169132b1b03139dd5c2d5674b49d962e2b21c40:RS5u7VxoR7EWCwTbXf5TXTt6SPCuUk6o3TU2UTS2bCkeW+nSU0tHRP2Kazl18qtbV7yLu6WYnSd4ydjW1BrZNw==:1000:SpM1Ltg3WC5CQYIMzzV35T1ICSOb97vrtDm/bFOYgfIl/qPwqaSobXEjEYhaWRg+R6acjWffnVGuAPYxScYe8A+6aJX5XYI915NfQNco3AW/8pqfgrzRSCrW3mMJM3Up51Fky1UkYfeOVN7E+JygbITWkr0GBQLZnhmFUUhOLWUmxfHKVSf8dThBh4MDlb6mZHPKaRo0ComWrqH1dU/EVQ==; KruxPixel=true; DoubleClickSession=true; _uetsid=f9f49310fdd311ec9900f1e9ea4088cf; _uetvid=ff286f40df4711ecaf2071c8bd8daea1; utag_main=v_id:01810fb763cc0090abcdead3546805073001706b00978{_sn:18$_se:1$_ss:1$_st:1657186541568$dc_visit:8$ses_id:1657184741568%3Bexp-session$_pn:1%3Bexp-session;} __gpi=UID=000005ec1e867d4f:T=1653826115:RT=1657184714:S=ALNI_MZQMCiY2HvhS99N9BBnDAldoQMEhg; _clck=3tvo9g|1|f2y|0; _clsk=1t5kg0o|1657184743519|1|0|a.clarity.ms/collect; KruxAddition=true; AWSALB=UxnJfJLnM73/54hRDda+HIXT9qjRXborvD2rh97Q24P6JuyT+wLfpOski5/Lt1ZlK82sEH+D6ztDB9wdHx0LDJ547Kct/hZOCbdrDvgUg7dKBWCEPRhzUMXB8xir; AWSALBCORS=UxnJfJLnM73/54hRDda+HIXT9qjRXborvD2rh97Q24P6JuyT+wLfpOski5/Lt1ZlK82sEH+D6ztDB9wdHx0LDJ547Kct/hZOCbdrDvgUg7dKBWCEPRhzUMXB8xir; search=6|1659777005448%7Crect%3D33.94155274805323%252C-84.21063931542969%252C33.60651471157812%252C-84.75034268457031%26rid%3D37211%26disp%3Dmap%26mdm%3Dauto%26p%3D1%26z%3D1%26fs%3D1%26fr%3D0%26mmm%3D0%26rs%3D0%26ah%3D0%26singlestory%3D0%26housing-connector%3D0%26abo%3D0%26garage%3D0%26pool%3D0%26ac%3D0%26waterfront%3D0%26finished%3D0%26unfinished%3D0%26cityview%3D0%26mountainview%3D0%26parkview%3D0%26waterview%3D0%26hoadata%3D1%26zillow-owned%3D0%263dhome%3D0%26featuredMultiFamilyBuilding%3D0%09%0937211%09%09%09%09%09%09; _gat=1",
    'sec-ch-ua': '".Not/A)Brand";v="99", "Google Chrome";v="103", "Chromium";v="103"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'document',
    'sec-fetch-mode': 'navigate',
    'sec-fetch-site': 'same-origin',
    'sec-fetch-user': '?1',
    'upgrade-insecure-requests': '1',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36',
}

# %%
with requests.Session() as s:
    city = 'Atlanta/'

# %%
    url = 'https://www.zillow.com/homes/for_sale/'+city
    url2 = 'https://www.zillow.com/homes/for_sale/'+city+'/2_p/'
    url3 = 'https://www.zillow.com/homes/for_sale/'+city+'/3_p/'
    url4 = 'https://www.zillow.com/homes/for_sale/'+city+'/4_p/'
    url5 = 'https://www.zillow.com/homes/for_sale/'+city+'/5_p/'
    url6 = 'https://www.zillow.com/homes/for_sale/'+city+'/6_p/'
    url7 = 'https://www.zillow.com/homes/for_sale/'+city+'/7_p/'
    url8 = 'https://www.zillow.com/homes/for_sale/'+city+'/8_p/'
    url9 = 'https://www.zillow.com/homes/for_sale/'+city+'/9_p/'
    url10 = 'https://www.zillow.com/homes/for_sale/'+city+'/10_p/'

# %%
    r = s.get(url, headers=req_headers)
    r2 = s.get(url2, headers=req_headers)
    r3 = s.get(url3, headers=req_headers)
    r4 = s.get(url4, headers=req_headers)
    r5 = s.get(url5, headers=req_headers)
    r6 = s.get(url6, headers=req_headers)
    r7 = s.get(url7, headers=req_headers)
    r8 = s.get(url8, headers=req_headers)
    r9 = s.get(url9, headers=req_headers)
    r10 = s.get(url10, headers=req_headers)

# %%
   url_links = [url, url2, url3, url4, url5, url6, url7, url8, url9, url10]

# %%
    print(url_links)
# Out:
# ['https://www.zillow.com/homes/for_sale/Atlanta/', 'https://www.zillow.com/homes/for_sale/Atlanta//2_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//3_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//4_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//5_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//6_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//7_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//8_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//9_p/', 'https://www.zillow.com/homes/for_sale/Atlanta//10_p/']

# %%
soup = BeautifulSoup(r.content, 'html.parser')
soup1 = BeautifulSoup(r2.content, 'html.parser')
soup2 = BeautifulSoup(r3.content, 'html.parser')
soup3 = BeautifulSoup(r4.content, 'html.parser')
soup4 = BeautifulSoup(r5.content, 'html.parser')
soup5 = BeautifulSoup(r6.content, 'html.parser')
soup6 = BeautifulSoup(r7.content, 'html.parser')
soup7 = BeautifulSoup(r8.content, 'html.parser')
soup8 = BeautifulSoup(r9.content, 'html.parser')
soup9 = BeautifulSoup(r10.content, 'html.parser')

# %%
table= pd.DataFrame(columns=["Address","Price","Detail","Links"])
houses = soup9.find_all('div', class_ = 'list-card-info')
for house in houses:
    try:
        address = house.find('address', {'class':'list-card-addr' }).text
        price = house.find('div', {'class':'list-card-price' }).text.split("$")[1].replace(",","")
        detail = house.find('ul', {'class':'list-card-details' }).text
        link = house.a['href']
        
        
    except Exception as e:
        address=None
        price=None
        detail=None
        link=None
    
    table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
                    ignore_index=True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/86381292.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/86381292.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/86381292.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# ...

# %%
table.head(24)
# Out:
#                                              Address    Price  \
# 0              1622 Beecher St SW, Atlanta, GA 30310   299000
# 1  3803 Chattahoochee Summit Dr SE #5, Atlanta, G...   469900
# 2          655 Mead St SE UNIT 11, Atlanta, GA 30312   425000
# 3   1080 Peachtree St NE UNIT 904, Atlanta, GA 30309   629900
# 4         223 W Paces Ferry Rd NW, Atlanta, GA 30305  4295000
# 5  1212 Utoy Springs Rd SW APT 32, Atlanta, GA 30331   120000
# 6    620 Glen Iris Dr NE UNIT 222, Atlanta, GA 30308   295000
# 7  480 John Wesley Dobbs Ave NE UNIT 608, Atlanta...   329000
# 8      174 Chester Ave SE UNIT 50, Atlanta, GA 30316   489000
# 9                                               None     None
#
#                                     Detail  \
# 0      3 bds1 ba1,721 sqft- House for sale
# 1  3 bds4 ba2,272 sqft- Townhouse for sale
# 2  2 bds2 ba1,686 sqft- Townhouse for sale
# 3      2 bds2 ba1,213 sqft- House for sale
# 4      3 bds5 ba7,852 sqft- House for sale
# ...

# %%
table1= pd.DataFrame(columns=["Address","Price","Detail","Links"])
houses1 = soup2.find_all('div', class_ = 'list-card-info')
for house in houses:
    try:
        address = house.find('address', {'class':'list-card-addr' }).text
        price = house.find('div', {'class':'list-card-price' }).text.split("$")[1].replace(",","")
        detail = house.find('ul', {'class':'list-card-details' }).text
        link = house.a['href']
        
        
    except Exception as e:
        address=None
        price=None
        detail=None
        link=None
    
    table1= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
                    ignore_index=True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/2132835931.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table1= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/2132835931.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table1= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/2132835931.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table1= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# ...

# %%
table1.head(24)
# Out:
#                                               Address    Price  \
# 0               1622 Beecher St SW, Atlanta, GA 30310   299000
# 1   3803 Chattahoochee Summit Dr SE #5, Atlanta, G...   469900
# 2           655 Mead St SE UNIT 11, Atlanta, GA 30312   425000
# 3    1080 Peachtree St NE UNIT 904, Atlanta, GA 30309   629900
# 4          223 W Paces Ferry Rd NW, Atlanta, GA 30305  4295000
# 5   1212 Utoy Springs Rd SW APT 32, Atlanta, GA 30331   120000
# 6     620 Glen Iris Dr NE UNIT 222, Atlanta, GA 30308   295000
# 7   480 John Wesley Dobbs Ave NE UNIT 608, Atlanta...   329000
# 8       174 Chester Ave SE UNIT 50, Atlanta, GA 30316   489000
# 9                                                None     None
# 10                                               None     None
#
#                                      Detail  \
# 0       3 bds1 ba1,721 sqft- House for sale
# 1   3 bds4 ba2,272 sqft- Townhouse for sale
# 2   2 bds2 ba1,686 sqft- Townhouse for sale
# ...

# %%
table= pd.DataFrame(columns=["Address","Price","Detail","Links"])
houses = soup7.find_all('div', class_ = 'list-card-info')
for house in houses:
    try:
        address = house.find('address', {'class':'list-card-addr' }).text
        price = house.find('div', {'class':'list-card-price' }).text.split("$")[1].replace(",","")
        detail = house.find('ul', {'class':'list-card-details' }).text
        link = house.a['href']
        
        
    except Exception as e:
        address=None
        price=None
        detail=None
        link=None
    
    table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
                    ignore_index=True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/1235464860.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/1235464860.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/1235464860.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# ...

# %%
table.head(24)
# Out:
#                                              Address    Price  \
# 0               502 Pryor Rd #309, Atlanta, GA 30312   209900
# 1      32 Peachtree St NW APT 704, Atlanta, GA 30303   219900
# 2               612 Clifton Rd NE, Atlanta, GA 30307  1095000
# 3      905 Juniper St NE UNIT 805, Atlanta, GA 30309   835000
# 4           967 Blue Ridge Ave NE, Atlanta, GA 30306  1150000
# 5       788 W Marietta St NW #911, Atlanta, GA 30318   358000
# 6  1740 Donald Lee Hollowell Pkwy NW, Atlanta, GA...   599999
# 7              Hayden Plan, The Villages at Oakshire  340490+
# 8            2319 Betty Ann Ct NW, Atlanta, GA 30318   625000
# 9                                               None     None
#
#                                   Detail  \
# 0    2 bds2 ba1,200 sqft- Condo for sale
# 1      2 bds2 ba902 sqft- Condo for sale
# 2    5 bds4 ba2,904 sqft- House for sale
# 3    3 bds3 ba1,889 sqft- Condo for sale
# 4    3 bds3 ba2,408 sqft- House for sale
# ...

# %%
table= pd.DataFrame(columns=["Address","Price","Detail","Links"])
houses = soup3.find_all('div', class_ = 'list-card-info')
for house in houses:
    try:
        address = house.find('address', {'class':'list-card-addr' }).text
        price = house.find('div', {'class':'list-card-price' }).text.split("$")[1].replace(",","")
        detail = house.find('ul', {'class':'list-card-details' }).text
        link = house.a['href']
        
        
    except Exception as e:
        address=None
        price=None
        detail=None
        link=None
    
    table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
                    ignore_index=True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/3620668484.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/3620668484.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/3620668484.py:17: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link},
# ...

# %%
table.head(24)
# Out:
#                                             Address   Price  \
# 0  2400 Campbellton Rd SW APT H4, Atlanta, GA 30311  125000
# 1             868 Oakhill Ave SW, Atlanta, GA 30310  229500
# 2        1398 Heights Park Dr SE, Atlanta, GA 30316  345000
# 3     2940 Benjamin E Mays Dr SW, Atlanta, GA 30311  380000
# 4          2574 Saint Paul Dr SW, Atlanta, GA 30331  555000
# 5      120 Biscayne Dr NW APT A2, Atlanta, GA 30309  234900
# 6            1411 Westmont Rd SW, Atlanta, GA 30311  349900
# 7              528 Bismark Rd NE, Atlanta, GA 30324  595000
# 8         94 Dew Drop Ln LOT 513, Atlanta, GA 30312  482875
# 9                                              None    None
#
#                                            Detail  \
# 0  -- bds-- ba-- sqft- Multi-family home for sale
# 1             3 bds2 ba1,278 sqft- House for sale
# 2         3 bds3 ba1,760 sqft- Townhouse for sale
# 3             6 bds3 ba3,356 sqft- House for sale
# ...

# %%
#print(soup9)

# %%
df = pd.DataFrame()
df1 = pd.DataFrame()

# %%
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')

# %%
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds

# %%
#create empty url list
urls = []

# %%
#loop through url, pull the href and strip out the address tag
for link in soup.find_all("article"):
    href = link.find('a',class_="list-card-link")
#     print(href)
    if href == None:
        addresses = None
#         addresses = 'zillow doesnt like this piece of code!'
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
#     print(addresses)
#     addresses = addresses.get_text()
#     addresses = href.find_all(href=True)
#     addresses = href.find('address class')
#     addresses.extract()
#     print(addresses)
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

df['links'] = urls
df['links'] = df['links'].astype('str')

# %%
for i in soup1:
    address1 = soup1.find_all (class_= 'list-card-addr')
    price1 = list(soup1.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup1.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup1.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup1.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup1.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup1.find_all (class_= 'list-card-link')

# %%
    df1['prices'] = price1
    df1['address'] = address1
    df1['beds'] = beds
#     df1['zestimate'] =

# %%
urls = []

# %%
for link in soup1.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df1['links'] = urls
df1['links'] = df1['links'].astype('str')

# %%
#df = df.append(df1, ignore_index = True)

# %%
df2 = pd.DataFrame()
df3 = pd.DataFrame()

# %%
for i in soup2:
    soup = soup2
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')
    
    #create dataframe columns out of variables
    df2['prices'] = price
    df2['address'] = address
    df2['beds'] = beds

# %%
time.sleep(3.2)

# %%
urls = []

# %%
for link in soup2.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df2['links'] = urls
df2['links'] = df2['links'].astype('str')

# %%
for i in soup3:
    soup = soup3
    address1 = soup.find_all (class_= 'list-card-addr')
    price1 = list(soup.find_all (class_='list-card-price'))
    beds1 = list(soup.find_all("ul", class_="list-card-details"))
    details1 = soup.find_all ('div', {'class': 'list-card-details'})
    home_type1 = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated1 = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage1 = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link1 = soup.find_all (class_= 'list-card-link')

    #create dataframe columns out of variables
    df3['prices'] = price1
    df3['address'] = address1
    df3['beds'] = beds

# %%
urls = []

# %%
for link in soup3.find_all("article"):
    href = link.find('a',class_="list-card-link")
    if href == None:
        addresses = None
    else:
        addresses = href.find('address',class_="list-card-addr").get_text()
    urls.append(addresses)
    urls = [x for x in urls if x is not None]

#import urls into a links column
df3['links'] = urls
df3['links'] = df3['links'].astype('str')

# %%
df = df.append(df1, ignore_index = True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_1120/3916347524.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df1, ignore_index = True)

# %%
df = df.append(df2, ignore_index = True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_1120/89406493.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df2, ignore_index = True)

# %%
df = df.append(df3, ignore_index = True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_1120/1464117959.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(df3, ignore_index = True)

# %%
df
# Out:
#           prices                                                   address                                                                              beds                                                   links
# 0     [$231,500]             [401 16th St NW UNIT 1479, Atlanta, GA 30363]       [[1, [ ,  , bd]], [1, [ ,  , ba]], [750, [ ,  , sqft]], [- Condo for sale]]             401 16th St NW UNIT 1479, Atlanta, GA 30363
# 1     [$254,900]                   [386 Sawtell Ave SE, Atlanta, GA 30315]      [[3, [ ,  , bds]], [2, [ ,  , ba]], [995, [ ,  , sqft]], [- House for sale]]                   386 Sawtell Ave SE, Atlanta, GA 30315
# 2     [$635,000]        [3338 Peachtree Rd NE APT 2105, Atlanta, GA 30326]    [[3, [ ,  , bds]], [3, [ ,  , ba]], [1,876, [ ,  , sqft]], [- Condo for sale]]        3338 Peachtree Rd NE APT 2105, Atlanta, GA 30326
# ...

# %%
#convert columns to str
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')

# %%
#remove html tags
df['prices'] = df['prices'].replace('<div class="list-card-price">', ' ', regex=True)
df['address'] = df['address'].replace('<address class="list-card-addr">', ' ', regex=True)
df['prices'] = df['prices'].replace('</div>', ' ', regex=True)
df['address'] = df['address'].replace('</address>', ' ', regex=True)
df['prices'] = df['prices'].str.replace(r'\D', '')
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_1120/3296115089.py:6: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['prices'] = df['prices'].str.replace(r'\D', '')

# %%
df.head(2)
# Out:
#      prices                                      address bed_bath_sqft                                      links
# 0  231500.0   401 16th St NW UNIT 1479 Atlanta GA 30363       1|1|750   401 16th St NW UNIT 1479 Atlanta GA 30363
# 1  254900.0         386 Sawtell Ave SE Atlanta GA 30315       3|2|995         386 Sawtell Ave SE Atlanta GA 30315

# %%
#remove html tags from beds column 
df['beds'] = df['beds'].replace('<ul class="list-card-details"><li class="">', ' ', regex=True)
df['beds'] = df['beds'].replace('<ul class="list-card-details"><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bds</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->ba</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bd</abbr></li><li>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace(' abbr></li><li class="">', '|', regex=True)
df['beds'] = df['beds'].replace('Studio</li><li>', '0 ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->ba</', ' ', regex=True)
df['beds'] = df['beds'].replace(' abbr></li><li class="">', '|', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">- House for sale</li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">- Condo for sale</li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->sqft</abbr></li><li class="list-card-statusText">-<abbr class="list-card-label"> <!-- -->Active</abbr></li></ul>', ' ', regex=True)
df['beds'] = df['beds'].replace('<abbr class="list-card-label"> <!-- -->bd</abbr></li><li class="">', '|', regex=True)

# %%
df.columns = ['prices','address','bed_bath_sqft','links']

# %%
#remove commas from sq_feet and convert to float
df.replace(',','', regex=True, inplace=True)

# %%
#convert column to float
df['prices'] = df['prices'].astype('float')

# %%
df.head(13)
# Out:
#        prices                                           address                                                                                                                  bed_bath_sqft                                           links
# 0    231500.0        401 16th St NW UNIT 1479 Atlanta GA 30363                                                                                                                        1|1|750        401 16th St NW UNIT 1479 Atlanta GA 30363
# 1    254900.0              386 Sawtell Ave SE Atlanta GA 30315                                                                                                                        3|2|995              386 Sawtell Ave SE Atlanta GA 30315
# 2    635000.0   3338 Peachtree Rd NE APT 2105 Atlanta GA 30326                                                                                                                       3|3|1876   3338 Peachtree Rd NE APT 2105 Atlanta GA 30326
# ...

# %%
df.to_csv("Zil_hin.csv")

# %%
Zillow_data = pd.read_csv("Zil_hin.csv")
Zillow_data.head(13)
# Out:
#     Unnamed: 0     prices                                           address                                                                                                                  bed_bath_sqft                                           links
# 0            0   231500.0        401 16th St NW UNIT 1479 Atlanta GA 30363                                                                                                                        1|1|750        401 16th St NW UNIT 1479 Atlanta GA 30363
# 1            1   254900.0              386 Sawtell Ave SE Atlanta GA 30315                                                                                                                        3|2|995              386 Sawtell Ave SE Atlanta GA 30315
# ...

# %%
sp=[9,2,7,3]

# %%
table= pd.DataFrame(columns=["Address","Price","Detail","Links"])
houses = soup6.find_all('div', class_ = 'list-card-info')
for house in houses:
    try:
        address = house.find('address', {'class':'list-card-addr' }).text
        price = house.find('div', {'class':'list-card-price' }).text.split("$")[1].replace(",","")
        detail = house.find('ul', {'class':'list-card-details' }).text
        brokerage = house(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
        link = house.a['href']
        
        
    except Exception as e:
        address=None
        price=None
        detail=None
        link=None
        brokerage=None
    
    table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link,"Brokerage":brokerage},
                    ignore_index=True)
# Out:
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/509222150.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link,"Brokerage":brokerage},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/509222150.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link,"Brokerage":brokerage},
# C:\Users\Asrar\AppData\Local\Temp/ipykernel_7636/509222150.py:19: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   table= table.append({"Address":address,"Price":price,"Detail":detail,"Links":link,"Brokerage":brokerage},
# ...

# %%
table.head(24)
# Out:
#                                         Address    Price  \
# 0        1697 Venetian Dr SW, Atlanta, GA 30311   199900
# 1     2659 Terrace Dr NE #13, Atlanta, GA 30305   384900
# 2          3633 Tuxedo Rd NW, Atlanta, GA 30305  5000000
# 3              Oakmont Plan, Camp Creek Village  422900+
# 4    2109 Pine Heights Dr NE, Atlanta, GA 30324   279000
# 5           1036 Linam St SE, Atlanta, GA 30315   315000
# 6  405 Fairburn Rd SW APT 17, Atlanta, GA 30331    62400
# 7       301 10th St NE APT 2, Atlanta, GA 30309   409900
# 8  943 Peachtree St UNIT 903, Atlanta, GA 30309   300000
# 9                                          None     None
#
#                                   Detail  \
# 0      2 bds1 ba846 sqft- House for sale
# 1  2 bds4 ba1,573 sqft- New construction
# 2    5 bds9 ba9,993 sqft- House for sale
# 3  4 bds3 ba2,340 sqft- New construction
# 4    2 bds2 ba1,249 sqft- Condo for sale
# 5    4 bds2 ba1,250 sqft- House for sale
# ...

# %%
print(soup6)
# Out:
# <!DOCTYPE html>
# <html class="no-js zsg-theme-modernized null" itemscope="" itemtype="http://schema.org/Organization" lang="en" xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="http://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#" xmlns:product="http://ogp.me/ns/product#">
# <head>
# <title>Atlanta GA Real Estate - Atlanta GA Homes For Sale | Zillow</title><meta content="Zillow has 2176 homes for sale in Atlanta GA. View listing photos, review sales history, and use our detailed real estate filters to find the perfect place." name="description"/><meta content="Zillow, Inc." name="author"/><meta content="Copyright (c) 2006-2022 Zillow, Inc." name="Copyright"/><script>
#         if (typeof Object.assign === 'function') {
#             window.appInfo = Object.assign(
#                 typeof window.appInfo === 'object' ? window.appInfo : {},
#                 {"@zillow/page-frame-content":"4da388b5"}
#             );
#         }
#     </script><script>
# ...

# %%
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all (class_='list-card-price'))
    beds = list(soup.find_all("ul", class_="list-card-details"))
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    link = soup.find_all (class_= 'list-card-link')

# %%
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds

# %%
df['prices'] = df['prices'].astype('str')
df['address'] = df['address'].astype('str')
df['beds'] = df['beds'].astype('str')

# %%
df=df[(df['prices'] != ' ') & (df['prices'] != ' ')]

# %%
df['prices']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5088/2600496404.py in <module>
# ----> 1 df['prices']
#
# TypeError: list indices must be integers or slices, not str

# %%
df=[['prices','address','beds']]

# %%
df
# Out:
# [['prices', 'address', 'beds']]

# %%
for i in soup:
    address = soup.find_all (class_= 'list-card-addr')
    price = list(soup.find_all ('div',{'class':'list-card-price'})
    #beds = list(soup.find_all('ul', {class:list-card-details'})
    details = soup.find_all ('div', {'class': 'list-card-details'})
    home_type = soup.find_all ('div', {'class': 'list-card-footer'})
    last_updated = soup.find_all ('div', {'class': 'list-card-top'})
    #brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay',text=True))
    brokerage = list(soup.find_all(class_= 'list-card-brokerage list-card-img-overlay provider-logo-overlay',text=True))                                   
    link = soup.find_all (class_= 'list-card-link')

# %%
#list-card-brokerage list-card-img-overlay provider-logo-overlay

# %%
    #create dataframe columns out of variables
    df['prices'] = price
    df['address'] = address
    df['beds'] = beds

# %%
df['prices'] = df['prices'].astype('str')

# %%
https://www.myfloridalicense.com/wl11.asp

# %%
import requests
from bs4 import BeautifulSoup

# Send an HTTP GET request to the web page
url = "https://www.myfloridalicense.com/wl11.asp"
response = requests.get(url)

# %%
response
# Out:
# <Response [200]>

# %%
# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the web page
    soup = BeautifulSoup(response.text, "html.parser")

    # Find and print the relevant data
    data = soup.find_all("a", {"class": "white_text"})
    for item in data:
        print(item.text)

else:
    print("Failed to retrieve the web page. Status code:", response.status_code)

# %%
import requests
from bs4 import BeautifulSoup

# Send an HTTP GET request to the URL
url = "https://www.myfloridalicense.com/wl11.asp"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the data you want to scrape (for example, scraping all links)
    links = soup.find_all('a')

    for link in links:
        print(link.get('href'))  # This will print the href attribute of each <a> element

    # You can adapt this code to scrape specific data you're interested in.

else:
    print("Failed to retrieve the web page. Status code:", response.status_code)
# Out:
# http://www.myfloridalicense.com/dbpr/
# http://www.myfloridalicense.com/dbpr/
# http://www.myfloridalicense.com/DBPR/contact-us/
# https://www.myfloridalicense.com/datamart/mainMenuFLDBPR.do
# http://www.myfloridalicense.com/DBPR/licensing-and-regulation/
# /wl11.asp?mode=0&SID=
# /wl11.asp?mode=0&SID=&brd=H
# http://www.myfloridalicense.com/DBPR/file-a-complaint/
# /CESearch.asp?SID=
# /viewapps.asp?SID=
# /examSchedule.asp?SID=
# /sto/unlicensedactivity/index.asp?SID=
# /delinquency_search.asp?SID=
# http://www.myfloridalicense.com/DBPR/instant-public-records/
# wl11.asp?mode=0&SID=&brd=&typ=
# http://maps.google.com/maps?f=q&source=s_q&hl=en&geocode=&q=2601+Blair+Stone+Road,+Tallahassee+FL+32399&sll=30.425336,-84.248805&ie=UTF8&hq=&hnear=2601+Blair+Stone+Rd,+Tallahassee,+Florida+32301&ll=30.425336,-84.248805&z=16
# http://www.myfloridalicense.com/contactus
# http://www.myflorida.com/myflorida/copyright.html
# http://www.myflorida.com/myflorida/privacy.html
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Send an HTTP GET request to the URL
url = "https://www.myfloridalicense.com/wl11.asp"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the data with proper headings and links
    data_with_headings = soup.find_all('td', style="height: 20px; background-color: #f7f7f7; font-size:14px; padding:7px 15px;")

    for item in data_with_headings:
        heading = item.find('a', class_='main')
        if heading:
            heading_text = heading.text
            link = item.find('a', href=True)
            if link:
                link_url = link['href']
                print(heading_text + " : " + link_url)

else:
    print("Failed to retrieve the web page. Status code:", response.status_code)
# Out:
# Verify a Licensee : /wl11.asp?mode=0&SID=
# View Food & Lodging Inspections : /wl11.asp?mode=0&SID=&brd=H
# File a Complaint : http://www.myfloridalicense.com/DBPR/file-a-complaint/
# Continuing Education Course Search : /CESearch.asp?SID=
# View Application Status : /viewapps.asp?SID=
# Find Exam Information : /examSchedule.asp?SID=
# Unlicensed Activity Search  : /sto/unlicensedactivity/index.asp?SID=

# %%
import requests
from bs4 import BeautifulSoup

# Send an HTTP GET request to the URL
url = "https://www.myfloridalicense.com/wl11.asp"
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page
    soup = BeautifulSoup(response.content, 'html.parser')

    # Find the link with the heading "Verify a Licensee"
    link = soup.find('a', text="Verify a Licensee")

    if link:
        link_url = link['href']
        print("Verify a Licensee Link:", link_url)
    else:
        print("Link not found")

else:
    print("Failed to retrieve the web page. Status code:", response.status_code)
# Out:
# Verify a Licensee Link: /wl11.asp?mode=0&SID=

# %% [markdown]
# #### Learn Web Scraping with Python BeautifulSoup || https://www.yellowpages.com/search?

# %%
import requests
from bs4 import BeautifulSoup
import csv

# %%
key = 'hotels'
location = 'Texas City, TX'

# %%
#req= requests.get(url,headders=headders)

# %%
key = 'hotels'
location = 'Texas City, TX'
url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page='.format(key, location)
headers = {
   'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
}
req = requests.get(url, headers=headers) # , headers=headers

# %%
print(req)
# Out:
# <Response [200]>

# %%
soup= BeautifulSoup(req.text,'html.parser')

# %%
items = soup.findAll('div','v-card')
for it in items:
      #name = it.find('h1', 'dockable business-name')
        name = it.find('a','business-name').text
        web= it.find()

# %%
print(name)
# Out:
# Holiday Inn Express & Suites Houston East - Beltway 8

# %%
key = 'hotels'
location = 'Texas City, TX'
url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page='.format(key, location)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
}
req = requests.get(url, headers=headers)

soup = BeautifulSoup(req.text, 'html.parser')
items = soup.findAll('div', 'v-card')

business_names = []  # Create a list to store business names

for item in items:
    name = item.find('a', 'business-name').text
    business_names.append(name)

# Print all the business names
for name in business_names:
    print(name)
# Out:
# Holiday Inn Express
# Holiday Inn
# Holiday Inn Express & Suites Houston East
# TownePlace Suites by Marriott Houston I-10 East
# Hampton Inn Houston I-10 East
# Diwali Houston East
# Regency Inn & Suites
# Best Western Plus Heritage Inn
# Candlewood Suites Houston I-10 East
# Holiday Inn Express
# Holiday Inn
# Travel Leaders
# Scottish Inn and Suites
# La Quinta Inn & Suites Houston - Normandy
# Prestige Expeditors
# Ellis Travel Agency
# Affordable Luxury Hotels For Less.
# Executive House
# Execustay
# Hyatt Regency Houston
# Horizon Travel LLC
# Goddess Travel
# Microtel Inn And Suites
# Granduca Luxury Residential Hotel
# Houston Inn and Suites
# Holiday Inn Express & Suites Houston East - Beltway 8
# Red Carpet Inn
# Palace Inn Blue I-45 & Woodridge
# Camelot Inn & Suites
# Clarion
# Embassy Suites by Hilton Houston Downtown
# SpringHill Suites by Marriott Houston Hobby Airport
# Holiday Inn Express
# Holiday Inn
# Holiday Inn & Suites Houston West - Katy Mills
# ...

# %%
import requests
from bs4 import BeautifulSoup

key = 'hotels'
location = 'Texas City, TX'
url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page='.format(key, location)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
}
req = requests.get(url, headers=headers)

soup = BeautifulSoup(req.text, 'html.parser')
items = soup.findAll('div', 'v-card')

business_data = []  # Create a list to store business data (name and web link)

for item in items:
    name = item.find('a', 'business-name').text
    web_link = item.find('a', class_='track-visit-website')
    if web_link:
        web_link = web_link['href']
    else:
        web_link = "Web link not found"

    business_data.append((name, web_link))

# Print or process the business data (name and web link)
for name, web_link in business_data:
    print("Name:", name)
    print("Web Link:", web_link)
    print()
# Out:
# Name: Holiday Inn Express
# Web Link: Web link not found
#
# Name: Holiday Inn
# Web Link: Web link not found
#
# Name: Holiday Inn Express & Suites Houston East
# Web Link: https://www.hiexpress.com/redirect?path=hd&brandCode=ex&hotelCode=houjc&_PMID=99601036&setPMCookies=true&cm_mmc=mdpr-_-dexess-_-ex-_-HOUJC&glat=MEDI
#
# Name: TownePlace Suites by Marriott Houston I-10 East
# Web Link: https://www.marriott.com/en-us/hotels/houeo-towneplace-suites-houston-i-10-east/overview
#
# Name: Hampton Inn Houston I-10 East
# Web Link: http://www.citysearch.com/profile/630879144/houston_tx/hampton_inn_houston_i_10_east.html
#
# Name: Regency Inn & Suites
# Web Link: http://regencyinnandsuites-i10east.yolasite.com
#
# Name: Best Western Plus Heritage Inn
# Web Link: https://www.bestwestern.com/en_US/book/hotel-rooms.44463.html?iata=00171890&ssob=BLBWI0003G&cid=BLBWI0003G:yext:website:44463
#
# Name: Candlewood Suites Houston I-10 East
# ...

# %%
import requests
from bs4 import BeautifulSoup

key = 'hotels'
location = 'Texas City, TX'
url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page='.format(key, location)
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
}
req = requests.get(url, headers=headers)

soup = BeautifulSoup(req.text, 'html.parser')
items = soup.findAll('div', 'v-card')

business_data = []  # Create a list to store business data (name, web link, and phone)

for item in items:
    name = item.find('a', 'business-name').text
    web_link = item.find('a', class_='track-visit-website')
    if web_link:
        web_link = web_link['href']
    else:
        web_link = "Web link not found"
    phone = item.find('div', 'phones phone primary')
    if phone:
        phone = phone.text
    else:
        phone = "Phone not found"

    business_data.append((name, web_link, phone))

# Print or process the business data (name, web link, and phone)
for name, web_link, phone in business_data:
    print("Name:", name)
    print("Web Link:", web_link)
    print("Phone:", phone)
    print()
# Out:
# Name: Holiday Inn Express
# Web Link: Web link not found
# Phone: Phone not found
#
# Name: Holiday Inn
# Web Link: Web link not found
# Phone: Phone not found
#
# Name: Holiday Inn Express & Suites Houston East
# Web Link: https://www.hiexpress.com/redirect?path=hd&brandCode=ex&hotelCode=houjc&_PMID=99601036&setPMCookies=true&cm_mmc=mdpr-_-dexess-_-ex-_-HOUJC&glat=MEDI
# Phone: (832) 914-1810
#
# Name: TownePlace Suites by Marriott Houston I-10 East
# Web Link: https://www.marriott.com/en-us/hotels/houeo-towneplace-suites-houston-i-10-east/overview
# Phone: (346) 381-1100
#
# Name: Hampton Inn Houston I-10 East
# Web Link: http://www.citysearch.com/profile/630879144/houston_tx/hampton_inn_houston_i_10_east.html
# Phone: (713) 997-8181
#
# Name: Diwali Houston East
# Web Link: Web link not found
# Phone: (713) 451-8374
#
# Name: Regency Inn & Suites
# Web Link: http://regencyinnandsuites-i10east.yolasite.com
# Phone: (713) 678-8222
#
# Name: Best Western Plus Heritage Inn
# ...

# %%
import requests
from bs4 import BeautifulSoup

key = 'hotels'
location = 'Texas City, TX'

business_data = []  # Create a list to store business data (name, web link, and phone)

for page in range(1, 6):  # Assuming you want to scrape the first 5 pages
    url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page={}'.format(key, location, page)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
    }
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    items = soup.findAll('div', 'v-card')

    for item in items:
        name = item.find('a', 'business-name').text
        web_link = item.find('a', class_='track-visit-website')
        if web_link:
            web_link = web_link['href']
        else:
            web_link = "Web link not found"
        
        phone = item.find('div', 'phones phone primary')
        if phone:
            phone = phone.text
        else:
            phone = "Phone not found"

        business_data.append((name, web_link, phone))

# Print or process the business data (name, web link, and phone)
for name, web_link, phone in business_data:
    print("Name:", name)
    print("Web Link:", web_link)
    print("Phone:", phone)
    print()
# Out:
# Name: Holiday Inn Express
# Web Link: Web link not found
# Phone: Phone not found
#
# Name: Holiday Inn
# Web Link: Web link not found
# Phone: Phone not found
#
# Name: Holiday Inn Express & Suites Houston East
# Web Link: https://www.hiexpress.com/redirect?path=hd&brandCode=ex&hotelCode=houjc&_PMID=99601036&setPMCookies=true&cm_mmc=mdpr-_-dexess-_-ex-_-HOUJC&glat=MEDI
# Phone: (832) 914-1810
#
# Name: TownePlace Suites by Marriott Houston I-10 East
# Web Link: https://www.marriott.com/en-us/hotels/houeo-towneplace-suites-houston-i-10-east/overview
# Phone: (346) 381-1100
#
# Name: Hampton Inn Houston I-10 East
# Web Link: http://www.citysearch.com/profile/630879144/houston_tx/hampton_inn_houston_i_10_east.html
# Phone: (713) 997-8181
#
# Name: Diwali Houston East
# Web Link: Web link not found
# Phone: (713) 451-8374
#
# Name: Regency Inn & Suites
# Web Link: http://regencyinnandsuites-i10east.yolasite.com
# Phone: (713) 678-8222
#
# Name: Best Western Plus Heritage Inn
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

key = 'hotels'
location = 'Texas City, TX'

business_data = []  # Create a list to store business data (name, web link, and phone)

for page in range(1, 6):  # Assuming you want to scrape the first 5 pages
    url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page={}'.format(key, location, page)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
    }
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    items = soup.findAll('div', 'v-card')

    for item in items:
        name = item.find('a', 'business-name').text
        web_link = item.find('a', class_='track-visit-website')
        if web_link:
            web_link = web_link['href']
        else:
            web_link = "Web link not found"
        
        phone = item.find('div', 'phones phone primary')
        if phone:
            phone = phone.text
        else:
            phone = "Phone not found"

        business_data.append((name, web_link, phone))

# Define the file path for the CSV file
file_path = r'C:\Users\Asrar\Downloads\business_data.csv'  # Use 'r' before the path to treat it as a raw string

# Save the business data as a CSV file
with open(file_path, 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['Name', 'Web Link', 'Phone'])  # Write the header
    for data in business_data:
        writer.writerow(data)

print(f"Scraped data saved to {file_path}")
# Out:
# Scraped data saved to C:\Users\Asrar\Downloads\business_data.csv

# %%
import requests
from bs4 import BeautifulSoup
import csv

key = 'hotels'
location = 'Texas City, TX'

business_data = []  # Create a list to store business data (name, web link, phone, and address)

for page in range(1, 6):  # Assuming you want to scrape the first 5 pages
    url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page={}'.format(key, location, page)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
    }
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    items = soup.findAll('div', 'v-card')

    for item in items:
        name = item.find('a', 'business-name').text
        web_link = item.find('a', class_='track-visit-website')
        if web_link:
            web_link = web_link['href']
        else:
            web_link = "Web link not found"
        
        phone = item.find('div', 'phones phone primary')
        if phone:
            phone = phone.text
        else:
            phone = "Phone not found"
        
        address = item.find('div', 'adr')
        if address:
            address = address.text
        else:
            address = "Address not found"

        business_data.append((name, web_link, phone, address))

# Define the file path for the CSV file
file_path =  r'C:\Users\Asrar\Downloads\business_data.csv' # Use 'r' before the path to treat it as a raw string

# Save the business data as a CSV file
with open(file_path, 'w', newline='') as csv_file:
    writer = csv.writer(csv_file)
    writer.writerow(['Name', 'Web Link', 'Phone', 'Address'])  # Write the header
    for data in business_data:
        writer.writerow(data)

print(f"Scraped data saved to {file_path}")
# Out:
# Scraped data saved to C:\Users\Asrar\Downloads\business_data.csv

# %%
business_data
# Out:
# [('Holiday Inn Express',
#   'Web link not found',
#   'Phone not found',
#   'Address not found'),
#  ('Holiday Inn', 'Web link not found', 'Phone not found', 'Address not found'),
#  ('Holiday Inn Express & Suites Houston East',
#   'https://www.hiexpress.com/redirect?path=hd&brandCode=ex&hotelCode=houjc&_PMID=99601036&setPMCookies=true&cm_mmc=mdpr-_-dexess-_-ex-_-HOUJC&glat=MEDI',
#   '(832) 914-1810',
#   '11460 East FwyHouston, TX 77029'),
#  ('TownePlace Suites by Marriott Houston I-10 East',
#   'https://www.marriott.com/en-us/hotels/houeo-towneplace-suites-houston-i-10-east/overview',
#   '(346) 381-1100',
#   '10507 East FwyHouston, TX 77029'),
#  ('Hampton Inn Houston I-10 East',
#   'http://www.citysearch.com/profile/630879144/houston_tx/hampton_inn_houston_i_10_east.html',
#   '(713) 997-8181',
#   '10505 East FwyHouston, TX 77029'),
#  ('Diwali Houston East',
#   'Web link not found',
#   '(713) 451-8374',
#   '11999 East FwyHouston, TX 77029'),
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

key = 'hotels'
location = 'Texas City, TX'

business_data = []  # Create a list to store business data (name and web link)

for page in range(1, 4):  # Assuming you want to scrape the first 5 pages
    url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page={}'.format(key, location, page)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
    }
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    items = soup.findAll('div', 'v-card')

    for item in items:
        name = item.find('a', 'business-name').text
        web_link = item.find('a', class_='track-visit-website')
        if web_link:
            web_link = web_link['href']
        else:
            web_link = "Web link not found"
        business_data.append((name, web_link))

# Save the data to a CSV file
with open('business_data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Web Link"])  # Write the header row
    for name, web_link in business_data:
        writer.writerow([name, web_link])

# %%
import requests
from bs4 import BeautifulSoup
import csv

key = 'hotels'
location = 'Texas City, TX'

business_data = []  # Create a list to store business data (name and web link)

for page in range(1, 6):  # Assuming you want to scrape the first 5 pages
    url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page={}'.format(key, location, page)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
    }
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    items = soup.findAll('div', 'v-card')

    for item in items:
        name = item.find('a', 'business-name').text
        web_link = item.find('a', class_='track-visit-website')
        if web_link:
            web_link = web_link['href']
        else:
            web_link = "Web link not found"
        business_data.append([name, web_link])

# Save the data to a CSV file
with open('business_data.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(["Name", "Web Link"])  # Write the header row
    for data in business_data:
        writer.writerow(data)

# %%
   business_data
# Out:
# [('Holiday Inn Express', 'Web link not found'),
#  ('Holiday Inn', 'Web link not found'),
#  ('Holiday Inn Express & Suites Houston East',
#   'https://www.hiexpress.com/redirect?path=hd&brandCode=ex&hotelCode=houjc&_PMID=99601036&setPMCookies=true&cm_mmc=mdpr-_-dexess-_-ex-_-HOUJC&glat=MEDI'),
#  ('TownePlace Suites by Marriott Houston I-10 East',
#   'https://www.marriott.com/en-us/hotels/houeo-towneplace-suites-houston-i-10-east/overview'),
#  ('Hampton Inn Houston I-10 East',
#   'http://www.citysearch.com/profile/630879144/houston_tx/hampton_inn_houston_i_10_east.html'),
#  ('Diwali Houston East', 'Web link not found'),
#  ('Regency Inn & Suites', 'http://regencyinnandsuites-i10east.yolasite.com'),
#  ('Best Western Plus Heritage Inn',
#   'https://www.bestwestern.com/en_US/book/hotel-rooms.44463.html?iata=00171890&ssob=BLBWI0003G&cid=BLBWI0003G:yext:website:44463'),
#  ('Candlewood Suites Houston I-10 East',
# ...

# %%
import requests
from bs4 import BeautifulSoup
import csv

key = 'hotels'
location = 'Texas City, TX'

business_data = []  # Create a list to store business data (name and web link)

for page in range(1, 3):  # Assuming you want to scrape the first 5 pages
    url = 'https://www.yellowpages.com/search?search_terms={}&geo_location_terms={}%20City%2C%20TX&page={}'.format(key, location, page)
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/118.0.0.0 Safari/537.36'
    }
    req = requests.get(url, headers=headers)
    soup = BeautifulSoup(req.text, 'html.parser')
    items = soup.findAll('div', 'v-card')

    for item in items:
        name = item.find('a', 'business-name').text
        web_link = item.find('a', class_='track-visit-website')
        if web_link:
            web_link = web_link['href']
        else:
            web_link = "Web link not found"
        business_data.append((name, web_link))

# Save business_data as a CSV file
with open('business_data.csv', 'w', newline='') as csvfile:
    csv_writer = csv.writer(csvfile)
    csv_writer.writerow(['Name', 'Web Link'])  # Write header
    csv_writer.writerows(business_data)  # Write data rows

print("business_data saved as business_data.csv")
# Out:
# business_data saved as business_data.csv

# %%
business_data
# Out:
# [('Holiday Inn Express', 'Web link not found'),
#  ('Holiday Inn', 'Web link not found'),
#  ('Holiday Inn Express & Suites Houston East',
#   'https://www.hiexpress.com/redirect?path=hd&brandCode=ex&hotelCode=houjc&_PMID=99601036&setPMCookies=true&cm_mmc=mdpr-_-dexess-_-ex-_-HOUJC&glat=MEDI'),
#  ('TownePlace Suites by Marriott Houston I-10 East',
#   'https://www.marriott.com/en-us/hotels/houeo-towneplace-suites-houston-i-10-east/overview'),
#  ('Hampton Inn Houston I-10 East',
#   'http://www.citysearch.com/profile/630879144/houston_tx/hampton_inn_houston_i_10_east.html'),
#  ('Diwali Houston East', 'Web link not found'),
#  ('Regency Inn & Suites', 'http://regencyinnandsuites-i10east.yolasite.com'),
#  ('Best Western Plus Heritage Inn',
#   'https://www.bestwestern.com/en_US/book/hotel-rooms.44463.html?iata=00171890&ssob=BLBWI0003G&cid=BLBWI0003G:yext:website:44463'),
#  ('Candlewood Suites Houston I-10 East',
# ...

# %%
items = soup.findAll('div', 'listing-card')
for item in items:
    name = item.find('h1', class_='dockable business-name')
    if name:
        business_name = name.text.strip()
        print("Business Name:", business_name)
    else:
        print("Business Name not found for this listing")

# %%
# ... (your previous code)

for it in items:
    name = it.find('a', class_='business-name')
    if name:
        business_name = name.get_text(strip=True)
        print("Business Name:", business_name)
    else:
        print("Business Name not found")

# ... (the rest of your code)

# %%
print(name)
# Out:
# <a class="business-name" data-analytics='{"target":"name","feature_click":""}' href="/houston-tx/mip/travel-leaders-544462390?lid=1002042933061" rel=""><span>Travel Leaders</span></a>

# %%
# ... (your previous code)

for it in items:
    name = it.find('a', class_='business-name')
    if name:
        business_name = name.get_text(strip=True)
        print("Business Name:", business_name)
    else:
        print("Business Name not found")

    # Extract address
    address = it.find('div', class_='street-address')
    if address:
        business_address = address.get_text(strip=True)
        print("Address:", business_address)
    else:
        print("Address not found")

    # Extract website
    website = it.find('a', class_='track-visit-website')
    if website:
        business_website = website['href']
        print("Website:", business_website)
    else:
        print("Website not found")

    # Extract telephone
    phone = it.find('div', class_='phones phone primary')
    if phone:
        business_phone = phone.get_text(strip=True)
        print("Telephone:", business_phone)
    else:
        print("Telephone not found")
            # Extract image
    image = it.find('img', class_='lazy')
    if image:
        business_image = image['data-original']
        print("Image:", business_image)
    else:
        print("Image not found")

# ... (the rest of your code)

# %%
# ... (your previous code)

for it in items:
    name = it.find('a', class_='business-name')
    if name:
        business_name = name.get_text(strip=True)
        print("Business Name:", business_name)
    else:
        print("Business Name not found")

    # Extract address
    address = it.find('div', class_='street-address')
    if address:
        business_address = address.get_text(strip=True)
        print("Address:", business_address)
    else:
        print("Address not found")

    # Extract website
    website = it.find('a', class_='track-visit-website')
    if website:
        business_website = website['href']
        print("Website:", business_website)
    else:
        print("Website not found")

    # Extract telephone
    phone = it.find('div', class_='phones phone primary')
    if phone:
        business_phone = phone.get_text(strip=True)
        print("Telephone:", business_phone)
    else:
        print("Telephone not found")

 

# # ... (the rest of your code)
